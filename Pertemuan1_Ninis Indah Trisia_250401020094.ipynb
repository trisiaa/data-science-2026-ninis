# %% [markdown]
# # **PRAKTIKUM PERTEMUAN 1 DATA SCIENCE**

# %% [markdown]
# Nama : Ninis Indah Trisia
#
# NIM : 250401020094
#
# Kelas : IF405

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Ninis Indah Trisia"
angkatan = 2025
ipk = 3.88
aktif = True

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Ninis Indah Trisia
# Angkatan: 2025
# IPK : 3.88
# Aktif : True

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Ninis Indah Trisia", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Ninis Indah Trisia dari Informatika, angkatan 2024.

# %% [markdown]
# ##Kesimpulan
#
# Pada praktikum pertama ini saya mempelajari dasar-dasar pemrograman Python yang menjadi fondasi dalam bidang data science. Materi yang dipraktikkan meliputi penggunaan perintah output (print), pembuatan variabel dengan berbagai tipe data, penggunaan list, perulangan (loop), serta pembuatan fungsi sederhana.
#
# Melalui latihan ini saya memahami bagaimana menyimpan dan menampilkan data menggunakan variabel, mengelola beberapa data dalam bentuk list, serta menampilkan isi list secara berurutan menggunakan perulangan. Selain itu, saya juga belajar membuat fungsi yang dapat menerima parameter dan menghasilkan output sesuai kebutuhan.
#
# Praktikum ini memberikan pemahaman awal tentang cara kerja program Python serta memperkenalkan beberapa tools yang umum digunakan dalam data science, seperti Python, Google Colab, Jupyter Notebook, dan GitHub. Meskipun masih sederhana, materi pada pertemuan ini menjadi dasar penting untuk mempelajari pengolahan dan analisis data pada praktikum-praktikum berikutnya.
